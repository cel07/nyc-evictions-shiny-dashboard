# %%
import os
import time
import requests
import pandas as pd

# %%
# Root project directoty (where this notebook lives)
PROJECT_ROOT = os.getcwd()

DATA_RAW_DIR = os.path.join(PROJECT_ROOT, "data_raw")
DATA_CLEAN_DIR = os.path.join(PROJECT_ROOT, "data_clean")
DATA_FINAL_DIR = os.path.join(PROJECT_ROOT, "data_final")

# Create directories if they don't exit
os.makedirs(DATA_RAW_DIR, exist_ok=True)
os.makedirs(DATA_CLEAN_DIR, exist_ok=True)
os.makedirs(DATA_FINAL_DIR, exist_ok=True)

PROJECT_ROOT, DATA_RAW_DIR
# Out:
# ('c:\\Users\\Christopher\\Documents\\Python Projects\\New_York_City_Eviction',
#  'c:\\Users\\Christopher\\Documents\\Python Projects\\New_York_City_Eviction\\data_raw')

# %%
BASE_URL = "https://data.cityofnewyork.us/resource/6z8x-wfk4.json"

# SODA2 pageination settings
LIMIT = 50000 # max rows per request (SODA2 usally caps at 50,00)
SLEEP_SECONDS = 0.25  # pause between calls to be polite / avoid throttling

# %%
def fetch_all_evictions(base_url: str, limit: int = 50000, sleep_seconds: float = 0.25):
    all_rows = []
    offset = 0
    batch_num =1

    while True:
        params = {
            "$limit": limit,
            "$offset": offset
        }

        print(f"Requesting batch {batch_num} | offset={offset} ...", end=" ")

        response = requests.get(base_url, params=params)
        response.raise_for_status()
        batch = response.json()

        batch_size = len(batch)
        print(f"received {batch_size} rows")

        if batch_size == 0:
            # No more data
            break

        all_rows.extend(batch)

        # Prepare next loop
        offset += limit
        batch_num += 1

        # Be gentle on the API
        time.sleep(sleep_seconds)

    print(f"\nDone. Total rows fetched: {len(all_rows)}")
    return all_rows

# %%
all_rows = fetch_all_evictions(BASE_URL, limit=LIMIT, sleep_seconds=SLEEP_SECONDS)

# Convert to DataFrame
evictions_raw = pd.DataFrame(all_rows)
print("DataFrame shape:", evictions_raw.shape)

# Save snapshot
raw_csv_path = os.path.join(DATA_RAW_DIR, "evictions_raw.csv")
evictions_raw.to_csv(raw_csv_path, index=False)

raw_csv_path
# Out:
# Requesting batch 1 | offset=0 ... received 50000 rows
# Requesting batch 2 | offset=50000 ... received 50000 rows
# Requesting batch 3 | offset=100000 ... received 20084 rows
# Requesting batch 4 | offset=150000 ... received 0 rows
#
# Done. Total rows fetched: 120084
# DataFrame shape: (120084, 20)
# 'c:\\Users\\Christopher\\Documents\\Python Projects\\New_York_City_Eviction\\data_raw\\evictions_raw.csv'

# %%
evictions_raw.head(20)
# Out:
#    court_index_number docket_number  \
# 0          B051541/15        360641
# 1             2141/19        351881
# 2           309099/23         17684
# 3            11149/16          5212
# 4             7463/19        489650
# 5           315671/23         18777
# 6           K58735/19        102435
# 7           092011/16        068058
# 8           079536/16        109572
# 9           318666/23        010447
# 10          318840/23        010993
# 11         R 50799/16        068517
# 12          050826/22        030927
# 13         302199/24B        146629
# 14           54933/17        292979
# 15           69408/17        295152
# 16          307421/23        124952
# 17          B42346/18        108958
# 18           89442/18        006885
# 19           59566/17        110005
#
#                                      eviction_address eviction_apt_num  \
# 0                                 120 WEST 183 STREET               15
# 1                                  1716 NEREID AVENUE                2
# 2                       728 E. 136TH STREET 2ND FLOOR              NaN
# 3                   1490 BRYANT AVE 3RD FL RIGHT SIDE              NaN
# 4                              767 EAST 229TH STREE T                *
# 5                     224 WEST 35TH STREET SUITE 1405              NaN
# 6                                   79 MILFORD STREET                3
# 7   2025 NOSTRAND AVENUE UNIT: GROUND FLOOR STORE ...              NaN
# 8                                    89-17 AUBREY AVE              NaN
# 9                                330 EAST 22ND STREET               4A
# 10                                 3303 FOSTER AVENUE               4D
# 11                                    255 YORK AVENUE              NaN
# 12                           1615 ALBANY AVE BASEMENT              NaN
# 13                               30 KENILWORTH AVENUE                -
# 14                                 58 MARBLE HILL AVE              C34
# 15                               143-54 ROOSEVELT AVE               2A
# 16                            65-25 ROOSEVELT AVEN UE               6B
# 17                                 1165 MORRIS AVENUE               3E
# 18                 226 FOURTH AVENUE  1ST FLOOR STORE              NaN
# 19                                   100-102 POST AVE               2K
#
#               executed_date marshal_first_name marshal_last_name  \
# 0   2017-01-05T00:00:00.000            Richard             McCoy
# 1   2019-04-26T00:00:00.000             Thomas               Bia
# 2   2023-12-15T00:00:00.000             Robert          Renzulli
# 3   2017-11-22T00:00:00.000             Robert          Renzulli
# 4   2019-06-13T00:00:00.000              Danny          Weinheim
# 5   2024-01-03T00:00:00.000             Robert          Renzulli
# 6   2022-06-01T00:00:00.000             Ileana            Rivera
# 7   2017-05-02T00:00:00.000              Henry             Daley
# 8   2017-08-01T00:00:00.000             Maxine          Chevlowe
# 9   2025-08-01T00:00:00.000              David             Smith
# 10  2025-06-30T00:00:00.000              David             Smith
# 11  2017-05-16T00:00:00.000             Steven            Powell
# 12  2023-05-16T00:00:00.000               Gary              Rose
# 13  2025-05-12T00:00:00.000             Justin          Grossman
# 14  2019-02-26T00:00:00.000             George            Essock
# 15  2017-11-15T00:00:00.000             George            Essock
# 16  2024-04-17T00:00:00.000             Justin          Grossman
# 17  2018-11-01T00:00:00.000            Darlene            Barone
# 18  2019-03-06T00:00:00.000              Frank          Siracusa
# 19  2017-08-21T00:00:00.000             Maxine          Chevlowe
#
#    residential_commercial_ind        borough eviction_zip         ejectment  \
# 0                 Residential          BRONX        10453  Not an Ejectment
# 1                 Residential          BRONX        10466  Not an Ejectment
# 2                  Commercial          BRONX        10454  Not an Ejectment
# 3                 Residential          BRONX        10460         Ejectment
# 4                 Residential          BRONX        10466  Not an Ejectment
# 5                  Commercial      MANHATTAN        10001  Not an Ejectment
# 6                 Residential       BROOKLYN        11208  Not an Ejectment
# 7                  Commercial       BROOKLYN        11210  Not an Ejectment
# 8                 Residential         QUEENS        11385  Not an Ejectment
# 9                 Residential       BROOKLYN        11226  Not an Ejectment
# 10                Residential       BROOKLYN        11210  Not an Ejectment
# 11                Residential  STATEN ISLAND        10301  Not an Ejectment
# 12                Residential       BROOKLYN        11210  Not an Ejectment
# 13                Residential  STATEN ISLAND        10312  Not an Ejectment
# 14                Residential      MANHATTAN        10463  Not an Ejectment
# 15                Residential         QUEENS        11354  Not an Ejectment
# 16                Residential         QUEENS        11377  Not an Ejectment
# 17                Residential          BRONX        10456  Not an Ejectment
# 18                 Commercial       BROOKLYN        11215  Not an Ejectment
# 19                Residential      MANHATTAN        10034  Not an Ejectment
#
#    eviction_possession   latitude   longitude community_board  \
# 0           Possession  40.859892  -73.910150               7
# 1           Possession  40.897898  -73.852183              12
# 2           Possession  40.803276  -73.913123               1
# 3           Possession        NaN         NaN             NaN
# 4           Possession  40.890068  -73.857116              12
# 5           Possession  40.752034  -73.991053               5
# 6           Possession  40.677955  -73.877926               5
# 7           Possession        NaN         NaN             NaN
# 8           Possession  40.711121  -73.862445               5
# 9           Possession  40.643188  -73.956482              14
# 10          Possession  40.638803  -73.945239              17
# 11          Possession  40.640097  -74.088001               1
# 12          Possession        NaN         NaN             NaN
# 13          Possession  40.564928  -74.183320               3
# 14          Possession  40.875720  -73.909702               8
# 15          Possession  40.761414  -73.822825               7
# 16          Possession  40.746149  -73.898163               2
# 17          Possession  40.832341  -73.914653               4
# 18          Possession        NaN         NaN             NaN
# 19          Possession  40.864275  -73.920838              12
#
#    council_district census_tract      bin         bbl  \
# 0                14          255  2014902  2032230034
# 1                11          434  2069945  2050480062
# 2                17           19  2003768  2025640047
# 3               NaN          NaN      NaN         NaN
# 4                12          422  2063589  2048430008
# 5                 3          109  1014414  1007840060
# 6                37         1192  3093108  3041530005
# 7               NaN          NaN      NaN         NaN
# 8                30          637  4094204  4038510145
# 9                40          792  3118875  3051650030
# 10               45          830  3327222  3049670040
# 11               49           77  5001076  5000470056
# 12              NaN          NaN      NaN         NaN
# 13               51        17007  5134130  5057270011
# 14               10          309  1064679  1022150555
# 15               20          855  4113658  4050230030
# 16               26          263  4619922  4012237503
# 17               16        18101  2002604  2024490072
# 18              NaN          NaN      NaN         NaN
# 19               10          293  1064783  1022220041
#
#                                           nta
# 0                         Kingsbridge Heights
# 1                          Woodlawn-Wakefield
# 2                      Mott Haven-Port Morris
# 3                                         NaN
# 4                    Williamsbridge-Olinville
# 5                       Midtown-Midtown South
# 6                               East New York
# 7                                         NaN
# 8                                    Glendale
# 9                                     Erasmus
# 10                     East Flatbush-Farragut
# 11  West New Brighton-New Brighton-St. George
# 12                                        NaN
# 13                              Arden Heights
# 14                         Marble Hill-Inwood
# 15                                   Flushing
# 16                                   Woodside
# 17           East Concourse-Concourse Village
# 18                                        NaN
# 19                         Marble Hill-Inwood

# %%
evictions_raw.dtypes
# Out:
# court_index_number            object
# docket_number                 object
# eviction_address              object
# eviction_apt_num              object
# executed_date                 object
# marshal_first_name            object
# marshal_last_name             object
# residential_commercial_ind    object
# borough                       object
# eviction_zip                  object
# ejectment                     object
# eviction_possession           object
# latitude                      object
# longitude                     object
# community_board               object
# council_district              object
# census_tract                  object
# bin                           object
# bbl                           object
# nta                           object
# dtype: object
